# %%
import pandas as pd

# %%
df = pd.read_csv('12bb84ed-397e-435c-8d1b-8ce543108698.csv')

# %%
df
# Out:
#          _id route ridership_route_code            route_full_name  \
# 0          1     1                  001          1 - FREEPORT ROAD
# 1          2     4                  004              4 - TROY HILL
# 2          3     6                  006            6 - SPRING HILL
# 3          4     8                  008            8 - PERRYSVILLE
# 4          5    11                  011              11 - FINEVIEW
# ...      ...   ...                  ...                        ...
# 20363  20732    Y1                  NaN           Y1 - LARGE FLYER
# 20364  20733   Y45                  NaN  Y45 - BALDWIN MANOR FLYER
# 20365  20734   Y46                  NaN      Y46 - ELIZABETH FLYER
# 20366  20735   Y47                  NaN          Y47 - CURRY FLYER
# 20367  20736   Y49                  NaN       Y49 - PROSPECT FLYER
#
#       current_garage mode month_start  year_month day_type   avg_riders  \
# 0               Ross  Bus  2017-01-01      201701     SAT.   969.500000
# ...

# %%
df['month_start'] = pd.to_datetime(df['month_start'])

# %%
df
# Out:
#          _id route ridership_route_code            route_full_name  \
# 0          1     1                  001          1 - FREEPORT ROAD
# 1          2     4                  004              4 - TROY HILL
# 2          3     6                  006            6 - SPRING HILL
# 3          4     8                  008            8 - PERRYSVILLE
# 4          5    11                  011              11 - FINEVIEW
# ...      ...   ...                  ...                        ...
# 20363  20732    Y1                  NaN           Y1 - LARGE FLYER
# 20364  20733   Y45                  NaN  Y45 - BALDWIN MANOR FLYER
# 20365  20734   Y46                  NaN      Y46 - ELIZABETH FLYER
# 20366  20735   Y47                  NaN          Y47 - CURRY FLYER
# 20367  20736   Y49                  NaN       Y49 - PROSPECT FLYER
#
#       current_garage mode month_start  year_month day_type   avg_riders  \
# 0               Ross  Bus  2017-01-01      201701     SAT.   969.500000
# ...
